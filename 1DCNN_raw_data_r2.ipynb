# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('data_augmented_syn_r2.csv', header=None)

# %%
df.shape
# Out:
# (2012, 211)

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x = np.reshape(x, (x.shape[0], x.shape[1], 1))

# %%
x[1].shape
# Out:
# (210, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train[0].shape
# Out:
# (210, 1)

# %%
from tensorflow.keras.layers import Flatten, Dense, Conv1D, MaxPool1D
from tensorflow.keras.models import Sequential

# %%
#create sequential model
model = Sequential()
#First CNN layer  with 32 filters,relu activation and same padding
model.add(Conv1D(filters=32, kernel_size=15, padding='same', activation='relu', input_shape=x_train[0].shape))
#second CNN layer with Max pooling
model.add(MaxPool1D(strides=2))
#Flatten the Output
model.add(Flatten())
#Adding a dense layer with 32 neurons
model.add(Dense(32, activation='relu'))
#Adding a dense layer with 64 neurons
model.add(Dense(64, activation='relu'))
#Softmax as last layer with 12 outputs
model.add(Dense(3, activation='softmax'))
model.build()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 210, 32)           512
#
#  max_pooling1d (MaxPooling1D  (None, 105, 32)          0
#  )
#
#  flatten (Flatten)           (None, 3360)              0
#
#  dense (Dense)               (None, 32)                107552
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 110,371
# Trainable params: 110,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train[..., None], y_train, epochs=100, batch_size=100, validation_data=(x_test[..., None],y_test))
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 15ms/step - loss: 27.9184 - accuracy: 0.3592 - val_loss: 18.2950 - val_accuracy: 0.3821
# Epoch 2/100
# 17/17 [==============================] - 0s 8ms/step - loss: 9.3676 - accuracy: 0.4897 - val_loss: 8.1278 - val_accuracy: 0.5261
# Epoch 3/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.7538 - accuracy: 0.5979 - val_loss: 3.2620 - val_accuracy: 0.5186
# Epoch 4/100
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0888 - accuracy: 0.6433 - val_loss: 1.0029 - val_accuracy: 0.6104
# Epoch 5/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9731 - accuracy: 0.7315 - val_loss: 0.8893 - val_accuracy: 0.6501
# Epoch 6/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8998 - accuracy: 0.7676 - val_loss: 0.8295 - val_accuracy: 0.6328
# Epoch 7/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6089 - accuracy: 0.7750 - val_loss: 0.7480 - val_accuracy: 0.6824
# Epoch 8/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5047 - accuracy: 0.8272 - val_loss: 0.6402 - val_accuracy: 0.7519
# Epoch 9/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4397 - accuracy: 0.8465 - val_loss: 0.6444 - val_accuracy: 0.7370
# Epoch 10/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3940 - accuracy: 0.8533 - val_loss: 0.6095 - val_accuracy: 0.7667
# Epoch 11/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3430 - accuracy: 0.8813 - val_loss: 0.5821 - val_accuracy: 0.7767
# Epoch 12/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3138 - accuracy: 0.8912 - val_loss: 0.5659 - val_accuracy: 0.7742
# Epoch 13/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2955 - accuracy: 0.8968 - val_loss: 0.5760 - val_accuracy: 0.7866
# Epoch 14/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2853 - accuracy: 0.9149 - val_loss: 0.6705 - val_accuracy: 0.7717
# Epoch 15/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2890 - accuracy: 0.9155 - val_loss: 0.5554 - val_accuracy: 0.8015
# Epoch 16/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2345 - accuracy: 0.9186 - val_loss: 0.5759 - val_accuracy: 0.7717
# Epoch 17/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2201 - accuracy: 0.9229 - val_loss: 0.5787 - val_accuracy: 0.7916
# Epoch 18/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1962 - accuracy: 0.9397 - val_loss: 0.5670 - val_accuracy: 0.7792
# Epoch 19/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1905 - accuracy: 0.9335 - val_loss: 0.5604 - val_accuracy: 0.7965
# Epoch 20/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1749 - accuracy: 0.9497 - val_loss: 0.5686 - val_accuracy: 0.8065
# Epoch 21/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.9503 - val_loss: 0.5640 - val_accuracy: 0.8040
# Epoch 22/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1494 - accuracy: 0.9602 - val_loss: 0.6014 - val_accuracy: 0.8114
# Epoch 23/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1590 - accuracy: 0.9503 - val_loss: 0.5852 - val_accuracy: 0.8065
# Epoch 24/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1364 - accuracy: 0.9646 - val_loss: 0.5899 - val_accuracy: 0.8015
# Epoch 25/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1291 - accuracy: 0.9633 - val_loss: 0.6122 - val_accuracy: 0.7891
# Epoch 26/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1200 - accuracy: 0.9702 - val_loss: 0.5941 - val_accuracy: 0.8164
# Epoch 27/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1247 - accuracy: 0.9621 - val_loss: 0.6171 - val_accuracy: 0.7916
# Epoch 28/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1053 - accuracy: 0.9751 - val_loss: 0.6307 - val_accuracy: 0.7965
# Epoch 29/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1149 - accuracy: 0.9683 - val_loss: 0.6415 - val_accuracy: 0.7990
# Epoch 30/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0961 - accuracy: 0.9776 - val_loss: 0.6474 - val_accuracy: 0.7965
# Epoch 31/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0969 - accuracy: 0.9776 - val_loss: 0.6996 - val_accuracy: 0.7916
# Epoch 32/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0979 - accuracy: 0.9720 - val_loss: 0.6450 - val_accuracy: 0.7990
# Epoch 33/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0751 - accuracy: 0.9901 - val_loss: 0.6979 - val_accuracy: 0.7816
# Epoch 34/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0856 - accuracy: 0.9845 - val_loss: 0.6981 - val_accuracy: 0.7742
# Epoch 35/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0972 - accuracy: 0.9714 - val_loss: 0.7077 - val_accuracy: 0.7916
# Epoch 36/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0646 - accuracy: 0.9913 - val_loss: 0.7208 - val_accuracy: 0.7990
# Epoch 37/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0650 - accuracy: 0.9894 - val_loss: 0.6963 - val_accuracy: 0.8065
# Epoch 38/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0559 - accuracy: 0.9938 - val_loss: 0.7069 - val_accuracy: 0.8089
# Epoch 39/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0509 - accuracy: 0.9950 - val_loss: 0.7217 - val_accuracy: 0.7965
# Epoch 40/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0471 - accuracy: 0.9956 - val_loss: 0.7309 - val_accuracy: 0.8089
# Epoch 41/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0433 - accuracy: 0.9969 - val_loss: 0.7437 - val_accuracy: 0.8065
# Epoch 42/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0417 - accuracy: 0.9969 - val_loss: 0.7674 - val_accuracy: 0.8089
# Epoch 43/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0383 - accuracy: 0.9963 - val_loss: 0.7769 - val_accuracy: 0.8040
# Epoch 44/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0368 - accuracy: 0.9969 - val_loss: 0.7799 - val_accuracy: 0.7866
# Epoch 45/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0359 - accuracy: 0.9969 - val_loss: 0.7820 - val_accuracy: 0.7990
# Epoch 46/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0337 - accuracy: 0.9969 - val_loss: 0.8211 - val_accuracy: 0.7841
# Epoch 47/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0343 - accuracy: 0.9969 - val_loss: 0.8262 - val_accuracy: 0.7916
# Epoch 48/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0324 - accuracy: 0.9969 - val_loss: 0.8625 - val_accuracy: 0.7767
# Epoch 49/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0352 - accuracy: 0.9963 - val_loss: 0.8271 - val_accuracy: 0.8015
# Epoch 50/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0263 - accuracy: 0.9969 - val_loss: 0.8235 - val_accuracy: 0.7940
# Epoch 51/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0255 - accuracy: 0.9969 - val_loss: 0.8482 - val_accuracy: 0.8040
# Epoch 52/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0241 - accuracy: 0.9969 - val_loss: 0.8597 - val_accuracy: 0.7940
# Epoch 53/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0234 - accuracy: 0.9969 - val_loss: 0.8632 - val_accuracy: 0.8040
# Epoch 54/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0214 - accuracy: 0.9969 - val_loss: 0.8766 - val_accuracy: 0.7990
# Epoch 55/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0204 - accuracy: 0.9969 - val_loss: 0.8808 - val_accuracy: 0.7990
# Epoch 56/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.9969 - val_loss: 0.8940 - val_accuracy: 0.7990
# Epoch 57/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.9969 - val_loss: 0.9002 - val_accuracy: 0.8015
# Epoch 58/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0186 - accuracy: 0.9969 - val_loss: 0.9168 - val_accuracy: 0.8015
# Epoch 59/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0209 - accuracy: 0.9969 - val_loss: 0.9407 - val_accuracy: 0.7841
# Epoch 60/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.9225 - val_accuracy: 0.8015
# Epoch 61/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0182 - accuracy: 0.9969 - val_loss: 0.9340 - val_accuracy: 0.7916
# Epoch 62/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0180 - accuracy: 0.9969 - val_loss: 0.9609 - val_accuracy: 0.7940
# Epoch 63/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0172 - accuracy: 0.9969 - val_loss: 0.9542 - val_accuracy: 0.7990
# Epoch 64/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0158 - accuracy: 0.9969 - val_loss: 0.9767 - val_accuracy: 0.7940
# Epoch 65/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0150 - accuracy: 0.9969 - val_loss: 0.9646 - val_accuracy: 0.7990
# Epoch 66/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0139 - accuracy: 0.9969 - val_loss: 0.9738 - val_accuracy: 0.7965
# Epoch 67/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0134 - accuracy: 0.9969 - val_loss: 0.9811 - val_accuracy: 0.7990
# Epoch 68/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.9841 - val_accuracy: 0.7965
# Epoch 69/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.9986 - val_accuracy: 0.7940
# Epoch 70/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.9951 - val_accuracy: 0.7940
# Epoch 71/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 0.9969 - val_loss: 1.0093 - val_accuracy: 0.7965
# Epoch 72/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 1.0169 - val_accuracy: 0.7965
# Epoch 73/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 1.0295 - val_accuracy: 0.7916
# Epoch 74/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 0.9969 - val_loss: 1.0291 - val_accuracy: 0.7940
# Epoch 75/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 1.0357 - val_accuracy: 0.7940
# Epoch 76/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 1.0431 - val_accuracy: 0.7866
# Epoch 77/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 1.0532 - val_accuracy: 0.7965
# Epoch 78/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 1.0573 - val_accuracy: 0.7940
# Epoch 79/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 1.0803 - val_accuracy: 0.7916
# Epoch 80/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 1.0833 - val_accuracy: 0.7965
# Epoch 81/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 1.0915 - val_accuracy: 0.7916
# Epoch 82/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 1.0878 - val_accuracy: 0.7916
# Epoch 83/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 1.0904 - val_accuracy: 0.7916
# Epoch 84/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 1.1027 - val_accuracy: 0.7866
# Epoch 85/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 1.1031 - val_accuracy: 0.7916
# Epoch 86/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 1.1064 - val_accuracy: 0.7916
# Epoch 87/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 1.1248 - val_accuracy: 0.7916
# Epoch 88/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 1.1189 - val_accuracy: 0.7916
# Epoch 89/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 1.1349 - val_accuracy: 0.7940
# Epoch 90/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 1.1437 - val_accuracy: 0.7891
# Epoch 91/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 1.1352 - val_accuracy: 0.7940
# Epoch 92/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 1.1461 - val_accuracy: 0.7916
# Epoch 93/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 1.1538 - val_accuracy: 0.7965
# Epoch 94/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 1.1580 - val_accuracy: 0.7965
# Epoch 95/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 1.1576 - val_accuracy: 0.7940
# Epoch 96/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 1.1630 - val_accuracy: 0.7916
# Epoch 97/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 1.1719 - val_accuracy: 0.7891
# Epoch 98/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 1.1903 - val_accuracy: 0.7916
# Epoch 99/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 1.1731 - val_accuracy: 0.7940
# Epoch 100/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 1.1778 - val_accuracy: 0.7940

# %%
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy for 1DCNN: %.2f' % (accuracy*100))
# Out:
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1778 - accuracy: 0.7940
# Accuracy for 1DCNN: 79.40

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('1DCNN Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()


# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('1DCNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix


# Generate predictions on test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Define class names
class_names = ['ethanol', 'ipa', 'methanol']

# Plot the confusion matrix
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=class_names,
       yticklabels=class_names,
       title='Confusion Matrix',
       ylabel='True Label',
       xlabel='Predicted Label')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Loop over data dimensions and create text annotations
fmt = 'd'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()
plt.show()
# Out:
# 13/13 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import classification_report

# Generate predictions on test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Print classification report
print(classification_report(y_test, y_pred_classes, target_names=class_names))
# Out:
# 13/13 [==============================] - 0s 988us/step
#               precision    recall  f1-score   support
#
#      ethanol       0.90      0.90      0.90       137
#          ipa       0.73      0.71      0.72       134
#     methanol       0.75      0.77      0.76       132
#
#     accuracy                           0.79       403
#    macro avg       0.79      0.79      0.79       403
# weighted avg       0.79      0.79      0.79       403
